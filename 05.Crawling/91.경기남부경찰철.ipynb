# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote
import pandas as pd
from selenium import webdriver
import warnings
import json, folium, warnings
warnings.filterwarnings('ignore')

# %%
base_url = 'https://www.ggpolice.go.kr'
main_url = '/main/html.do?menu=HC44'
url = f'{base_url}{main_url}'
result = requests.get(url)
soup = BeautifulSoup(result.text)
driver =webdriver.Chrome('file:///C:/Users/YONSAI/Downloads/chromedriver_win32/chromedriver')
driver.get(url)

# %%
soup =BeautifulSoup(driver.page_source)
lis =soup.select('.road')
len(lis)
# Out:
# 31

# %% [markdown]
# ##### 3. 하나의 데이터로 원하는 정보 추출

# %%
li =lis[0]
sub_url = li.select_one('li > a')['href']
sub_url
# Out:
# 'https://www.ggpolice.go.kr/swjb/html.do?menu=HC24'

# %%
res =requests.get(sub_url)
title_soup = BeautifulSoup(res.text)

# %%
info =title_soup.select_one('.basic_list7')
title_b =info.find_all('li')
title_b
# Out:
# [<li>기관명 : 수원중부경찰서</li>,
#  <li>도로명 주소 : 경기도 수원시 장안구 정자천로 199 (우)16335</li>,
#  <li>대표전화 : 경찰민원 콜센터 182</li>]

# %%
# police = info.select('.basic_list7 > li')
# for li in police:
#     print(li.get_text())

# %%
police_dict ={}
for li in title_b:
    item =li.get_text().split(':')
    police_dict[item[0].strip()] =item[1].strip()
police_dict
# Out:
# {'기관명': '수원중부경찰서',
#  '도로명 주소': '경기도 수원시 장안구 정자천로 199 (우)16335',
#  '대표전화': '경찰민원 콜센터 182'}

# %%
name =police_dict['기관명'].split(' , ')
name
# Out:
# ['수원중부경찰서']

# %%
address =police_dict['도로명 주소'].split(' , ')
address
# Out:
# ['경기도 수원시 장안구 정자천로 199 (우)16335']

# %%
lines =[]
for li in lis:
    sub_url = li.select_one('li > a')['href']
    res =requests.get(sub_url)
    try:
        title_soup = BeautifulSoup(res.text)
        info =title_soup.select_one('.basic_list7')
        title_b =info.find_all('li')
        police = info.select('.basic_list7 > li')
        for li in police:
                item =li.get_text().split(':')
                police_dict[item[0].strip()] =item[1].strip()
        name =( police_dict['기관명'])
        address =( police_dict['도로명 주소']).split('(')[0].strip()
        lines.append({'기관명':name,'주소':address})
    except:
        continue

# %%
df=pd.DataFrame(lines)
df
# Out:
#         기관명                       주소
# 0   수원중부경찰서     경기도 수원시 장안구 정자천로 199
# 1   수원남부경찰서        경기 수원시 영통구 매봉로 52
# 2   수원서부경찰서      경기 수원시 권선구 서부로 1673
# 3   안양동안경찰서  경기도 안양시 동안구 동안로159번길 43
# 4   안양만안경찰서       경기도 안양시 만안구 냉천로 63
# 5     과천경찰서            경기 과천시 통영로 20
# 6   성남수정경찰서     경기 성남시 수정구 성남대로 1259
# 7   성남중원경찰서     경기 성남시 중원구 금빛로2번길 10
# 8     분당경찰서      경기 성남시 분당구 정자일로 165
# 9   부천소사경찰서          경기 부천시  부광로 214
# 10  부천원미경찰서      경기 부천시 조마루로311번길 84
# 11  부천오정경찰서           경기 부천시 소사로 631
# 12  안산단원경찰서      경기도 안산시 단원구 화랑로 373
# 13  안산상록경찰서      경기 안산시 상록구 차돌배기로 10
# 14    시흥경찰서          경기 시흥시 황고개로 513
# 15    평택경찰서           경기도 평택시 중앙로 67
# 16    오산경찰서          경기 오산시 동부대로 596
# 17  화성동탄경찰서      경기도 화성시 동탄대로 13길 70
# 18  화성서부경찰서       경기 화성시 남양읍 남양로 570
# 19  용인동부경찰서       경기 용인시 처인구 금학로 143
# 20  수원남부경찰서        경기 수원시 영통구 매봉로 52
# 21    광주경찰서          경기 광주시 포돌이로 135
# 22    이천경찰서            경기 이천시 부악로 32
# 23    안성경찰서          경기 안성시 알미산로 140
# 24    여주경찰서            경기 여주시 세종로 50
# 25    양평경찰서       경기도 양평군 옥천면 고읍로 88
# 26    의왕경찰서            경기 의왕시 오봉로 10
# 27    하남경찰서            경기 하남시 검단로 27

# %%
with open('../04. 지도시각화/data/kakaoapikey.txt') as f:
    kakao_key =f.read()
base_url ='https://dapi.kakao.com/v2/local/search/address.json'
addr ='경기도 수원시 장안구 정자천로 199'                #샘플
url = f'{base_url}?query={quote(addr)}'
header = {'Authorization':f'KakaoAK {kakao_key}'}
result = requests.get(url, headers=header).json()
result
# Out:
# {'documents': [{'address': {'address_name': '경기 수원시 장안구 정자동 873-4',
#     'b_code': '4111113000',
#     'h_code': '4111157300',
#     'main_address_no': '873',
#     'mountain_yn': 'N',
#     'region_1depth_name': '경기',
#     'region_2depth_name': '수원시 장안구',
#     'region_3depth_h_name': '정자3동',
#     'region_3depth_name': '정자동',
#     'sub_address_no': '4',
#     'x': '126.99631718583',
#     'y': '37.2979319496338'},
#    'address_name': '경기 수원시 장안구 정자천로 199',
#    'address_type': 'ROAD_ADDR',
#    'road_address': {'address_name': '경기 수원시 장안구 정자천로 199',
#     'building_name': '수원중부경찰서',
#     'main_building_no': '199',
#     'region_1depth_name': '경기',
#     'region_2depth_name': '수원시 장안구',
#     'region_3depth_name': '정자동',
#     'road_name': '정자천로',
#     'sub_building_no': '',
#     'underground_yn': 'N',
#     'x': '126.99631718583',
#     'y': '37.2979319496338',
#     'zone_no': '16335'},
#    'x': '126.99631718583',
#    'y': '37.2979319496338'}],
#  'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}

# %%
result['documents'][0].keys()
# Out:
# dict_keys(['address', 'address_name', 'address_type', 'road_address', 'x', 'y'])

# %%
lat = float(result['documents'][0]['y'])
lng = float(result['documents'][0]['x'])
lat,lng
# Out:
# (37.2979319496338, 126.99631718583)

# %%
lat_list,lng_list =[],[]
for i in df.index:
    url = f'{base_url}?query={quote(df.주소[i])}'
    result = requests.get(url, headers=header).json()
    lat_list.append(float(result['documents'][0]['y']))
    lng_list.append(float(result['documents'][0]['x']))

# %%
df['위도'] = lat_list
df['경도'] = lng_list
df
# Out:
#         기관명                       주소         위도          경도
# 0   수원중부경찰서     경기도 수원시 장안구 정자천로 199  37.297932  126.996317
# 1   수원남부경찰서        경기 수원시 영통구 매봉로 52  37.272104  127.054492
# 2   수원서부경찰서      경기 수원시 권선구 서부로 1673  37.258740  126.972264
# 3   안양동안경찰서  경기도 안양시 동안구 동안로159번길 43  37.391209  126.948866
# 4   안양만안경찰서       경기도 안양시 만안구 냉천로 63  37.387334  126.925974
# 5     과천경찰서            경기 과천시 통영로 20  37.429358  126.989987
# 6   성남수정경찰서     경기 성남시 수정구 성남대로 1259  37.442287  127.126662
# 7   성남중원경찰서     경기 성남시 중원구 금빛로2번길 10  37.442664  127.170371
# 8     분당경찰서      경기 성남시 분당구 정자일로 165  37.365305  127.105450
# 9   부천소사경찰서          경기 부천시  부광로 214  37.468723  126.824181
# 10  부천원미경찰서      경기 부천시 조마루로311번길 84  37.502463  126.777337
# 11  부천오정경찰서           경기 부천시 소사로 631  37.514495  126.800321
# 12  안산단원경찰서      경기도 안산시 단원구 화랑로 373  37.321950  126.829564
# 13  안산상록경찰서      경기 안산시 상록구 차돌배기로 10  37.299196  126.845188
# 14    시흥경찰서          경기 시흥시 황고개로 513  37.376785  126.788109
# 15    평택경찰서           경기도 평택시 중앙로 67  36.994847  127.090958
# 16    오산경찰서          경기 오산시 동부대로 596  37.153637  127.082246
# 17  화성동탄경찰서      경기도 화성시 동탄대로 13길 70  37.185728  127.094115
# 18  화성서부경찰서       경기 화성시 남양읍 남양로 570  37.191338  126.822491
# 19  용인동부경찰서       경기 용인시 처인구 금학로 143  37.241558  127.180431
# 20  수원남부경찰서        경기 수원시 영통구 매봉로 52  37.272104  127.054492
# 21    광주경찰서          경기 광주시 포돌이로 135  37.408822  127.239490
# 22    이천경찰서            경기 이천시 부악로 32  37.273597  127.434764
# 23    안성경찰서          경기 안성시 알미산로 140  37.000492  127.249659
# 24    여주경찰서            경기 여주시 세종로 50  37.293205  127.635529
# 25    양평경찰서       경기도 양평군 옥천면 고읍로 88  37.516925  127.454997
# 26    의왕경찰서            경기 의왕시 오봉로 10  37.345198  126.974049
# 27    하남경찰서            경기 하남시 검단로 27  37.522672  127.224643

# %%
map = folium.Map(location=[df.위도.mean(),df.경도.mean()], zoom_start=12)
for i in df.index:
    folium.Marker(
        location=[df.위도[i],df.경도[i]],
        popup=folium.Popup(df.주소[i],max_width=200),
        tooltip=df.기관명[i],
        icon=folium.Icon(
        color ='purple',icon_color='white',
        icon='glyphicon glyphicon-pushpin', #glyphicon 아이콘 제공 사이트
        prefix='glyphicon'
    )
    ).add_to(map)
title_html ='<h3 align="center" style ="font-size:20px">경기남부경찰</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f7f5dfc659712af342846854de6f974 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style =&quot;font-size:20px&quot;&gt;경기남부경찰&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f7f5dfc659712af342846854de6f974&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f7f5dfc659712af342846854de6f974 = L.map(
#                 &quot;map_9f7f5dfc659712af342846854de6f974&quot;,
#                 {
#                     center: [37.327523895890444, 127.06046237522362],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3da0c176399fe5f65c8ca0860063412c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f7f5dfc659712af342846854de6f974);
#
#
#             var marker_0fcfbee2fa140b48ad889fe34e1b4ff2 = L.marker(
#                 [37.2979319496338, 126.99631718583],
#                 {}
#             ).addTo(map_9f7f5dfc659712af342846854de6f974);
#
#
#             var icon_c3a2fab59ad63304e44b5bcbf3d859b4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-pushpin&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0fcfbee2fa140b48ad889fe34e1b4ff2.setIcon(icon_c3a2fab59ad63304e44b5bcbf3d859b4);
#
#
#         var popup_f6b0a47efadff8f4c443c020215d92f2 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_b527d67dd07ceef7ccc4a88391b56824 = $(`&lt;div id=&quot;html_b527d67dd07ceef7ccc4a88391b56824&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 장안구 정자천로 199&lt;/div&gt;`)[0];
#                 popup_f6b0a47efadff8f4c443c020215d92f2.setContent(html_b527d67dd07ceef7ccc4a88391b56824);
#
#
#
#         marker_0fcfbee2fa140b48ad889fe34e1b4ff2.bindPopup(popup_f6b0a47efadff8f4c443c020215d92f2)
#         ;
#
#
#
#
#             marker_0fcfbee2fa140b48ad889fe34e1b4ff2.bindTooltip(
#                 `&lt;div&gt;
#                      수원중부경찰서
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a649fad762f0590ed46549b87b6f36f4 = L.marker(
#                 [37.2721043390665, 127.054492051642],
#                 {}
#             ).addTo(map_9f7f5dfc659712af342846854de6f974);
#
#
#             var icon_035cd982c1c648acc1955a1501b6b7b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-pushpin&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a649fad762f0590ed46549b87b6f36f4.setIcon(icon_035cd982c1c648acc1955a1501b6b7b0);
#
#
#         var popup_89e4207df9bea5c7031078318a901c1a = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_a3208e939c47d8dc4b0e390fc08252e4 = $(`&lt;div id=&quot;html_a3208e939c47d8dc4b0e390fc08252e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기 수원시 영통구 매봉로 52&lt;/div&gt;`)[0];
#                 popup_89e4207df9bea5c7031078318a901c1a.setContent(html_a3208e939c47d8dc4b0e390fc08252e4);
#
#
#
#         marker_a649fad762f0590ed46549b87b6f36f4.bindPopup(popup_89e4207df9bea5c7031078318a901c1a)
#         ;
#
#
#
#
#             marker_a649fad762f0590ed46549b87b6f36f4.bindTooltip(
#                 `&lt;div&gt;
#                      수원남부경찰서
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_179d85ff0de8919e95bf410b6c4b1eb7 = L.marker(
#                 [37.2587398262097, 126.97226385575],
#                 {}
#             ).addTo(map_9f7f5dfc659712af342846854de6f974);
#
#
#             var icon_f6008331a66070a6db7a8448cd8a9d11 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-pushpin&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_179d85ff0de8919e95bf410b6c4b1eb7.setIcon(icon_f6008331a66070a6db7a8448cd8a9d11);
#
#
#         var popup_4dac939bdd700d3d59eae4cbc8f8aea1 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_304cb4639d1f718bdfbac930ae070cf0 = $(`&lt;div id=&quot;html_304cb4639d1f718bdfbac930ae070cf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기 수원시 권선구 서부로 1673&lt;/div
