# %% [markdown]
# ### 경기도 남부 경찰청
# - 산하 경찰서를 크롤링하여 지도에 표시하기

# %%
import requests, folium
import pandas as pd
from urllib.parse import quote
from bs4 import BeautifulSoup

# %% [markdown]
# - Step 1, 2

# %%
url = 'https://www.ggpolice.go.kr/main/html.do?menu=HC44'
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

# %%
lis = soup.select('li.road')
len(lis)
# Out:
# 31

# %% [markdown]
# - Step 3.

# %%
li = lis[0]
name = li.find('a').string.strip()
href = li.find('a')['href']
name, href
# Out:
# ('수원중부서', 'https://www.ggpolice.go.kr/swjb/html.do?menu=HC24')

# %%
sub_res = requests.get(href)
sub_soup = BeautifulSoup(sub_res.text, 'html.parser')

# %%
sub_lis = sub_soup.select('.basic_list7 > li')
len(sub_lis)
# Out:
# 3

# %%
name = sub_lis[0].get_text().strip()[6:]
name
# Out:
# '수원중부경찰서'

# %%
addr = sub_lis[1].get_text().strip()[9:-9]
addr
# Out:
# '경기도 수원시 장안구 정자천로 199'

# %% [markdown]
# - Step 4

# %%
lines = []
for li in lis:
    href = li.find('a')['href']
    sub_res = requests.get(href)
    sub_soup = BeautifulSoup(sub_res.text, 'html.parser')
    sub_lis = sub_soup.select('.basic_list7 > li')
    name = sub_lis[0].get_text().strip()[6:]
    addr = sub_lis[1].get_text().strip()[9:-9]
    lines.append({'name':name, 'addr':addr})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 7
#       5 sub_soup = BeautifulSoup(sub_res.text, 'html.parser')
#       6 sub_lis = sub_soup.select('.basic_list7 > li')
# ----> 7 name = sub_lis[0].get_text().strip()[6:]
#       8 addr = sub_lis[1].get_text().strip()[9:-9]
#       9 lines.append({'name':name, 'addr':addr})
#
# IndexError: list index out of range

# %% [markdown]
# - Step 5. 오류 해결
#     - 어디서 발생했는지 파악
#     - 파악한 곳으로 가서 해결

# %%
# 어디서 에러가 발생했는지 파악
lines = []
for index, li in enumerate(lis):
    try:
        href = li.find('a')['href']
        sub_res = requests.get(href)
        sub_soup = BeautifulSoup(sub_res.text, 'html.parser')
        sub_lis = sub_soup.select('.basic_list7 > li')
        name = sub_lis[0].get_text().strip()[6:]
        addr = sub_lis[1].get_text().strip()[9:-9]
        lines.append({'name':name, 'addr':addr})
    except:
        print(index)
# Out:
# 6
# 25

# %%
# 에러를 찾아서 해결
# index=6, 군포경찰서로 찾아가서 원인 파악
li = lis[6]
href = li.find('a')['href']
print(href)
sub_res = requests.get(href)
sub_soup = BeautifulSoup(sub_res.text, 'html.parser')
sub_lis = sub_soup.select('.basic_list7 > li')
print(len(sub_lis))
# Out:
# https://www.ggpolice.go.kr/gunpo/html.do?menu=HC24
# 0

# %%
lines = []
for li in lis:
    href = li.find('a')['href']
    sub_res = requests.get(href)
    sub_soup = BeautifulSoup(sub_res.text, 'html.parser')
    sub_lis = sub_soup.select('.basic_list7 > li')
    if len(sub_lis) == 0:
        continue
    name = sub_lis[0].get_text().strip()[6:]
    addr = sub_lis[1].get_text().strip()[9:-9]
    lines.append({'name':name, 'addr':addr})

# %%
# 정확한 원인을 찾지 못하는 경우, just skip
lines = []
for li in lis:
    try:
        href = li.find('a')['href']
        sub_res = requests.get(href)
        sub_soup = BeautifulSoup(sub_res.text, 'html.parser')
        sub_lis = sub_soup.select('.basic_list7 > li')
        name = sub_lis[0].get_text().strip()[6:]
        addr = sub_lis[1].get_text().strip()[9:-9]
        lines.append({'name':name, 'addr':addr})
    except:
        continue

# %% [markdown]
# - Step 7

# %%
df = pd.DataFrame(lines)
print(df.shape)
df
# Out:
# (29, 2)
#        name                     addr
# 0   수원중부경찰서     경기도 수원시 장안구 정자천로 199
# 1   수원남부경찰서        경기 수원시 영통구 매봉로 52
# 2   수원서부경찰서      경기 수원시 권선구 서부로 1673
# 3   안양동안경찰서  경기도 안양시 동안구 동안로159번길 43
# 4   안양만안경찰서       경기도 안양시 만안구 냉천로 63
# 5     과천경찰서            경기 과천시 통영로 20
# 6   성남수정경찰서     경기 성남시 수정구 성남대로 1259
# 7   성남중원경찰서     경기 성남시 중원구 금빛로2번길 10
# 8     분당경찰서      경기 성남시 분당구 정자일로 165
# 9   부천소사경찰서          경기 부천시  부광로 214
# 10  부천원미경찰서      경기 부천시 조마루로311번길 84
# 11  부천오정경찰서           경기 부천시 소사로 631
# 12    광명경찰서            경기 광명시 디지털로 5
# 13  안산단원경찰서      경기도 안산시 단원구 화랑로 373
# 14  안산상록경찰서      경기 안산시 상록구 차돌배기로 10
# 15    시흥경찰서          경기 시흥시 황고개로 513
# 16    평택경찰서           경기도 평택시 중앙로 67
# 17    오산경찰서          경기 오산시 동부대로 596
# 18  화성동탄경찰서        경기도 화성시 동탄대로 13길
# 19  화성서부경찰서       경기 화성시 남양읍 남양로 570
# 20  용인동부경찰서       경기 용인시 처인구 금학로 143
# 21  수원남부경찰서        경기 수원시 영통구 매봉로 52
# 22    광주경찰서          경기 광주시 포돌이로 135
# 23    이천경찰서            경기 이천시 부악로 32
# 24    안성경찰서          경기 안성시 알미산로 140
# 25    여주경찰서            경기 여주시 세종로 50
# 26    양평경찰서         경기도 양평군 옥천면 고읍로
# 27    의왕경찰서            경기 의왕시 오봉로 10
# 28    하남경찰서            경기 하남시 검단로 27

# %%
# 중복 여부 확인
len(df.name.unique())
# Out:
# 28

# %%
# 중복 제거
df.drop_duplicates(subset='name', inplace=True)
df.shape
# Out:
# (28, 2)

# %% [markdown]
# ##### 위도, 경도 정보 얻기

# %%
with open('../04. 지도시각화/data/kakaoapikey.txt') as f:
    kakao_key =f.read()

# %%
base_url = 'https://dapi.kakao.com/v2/local/search/address.json'
header = {'Authorization': f'KakaoAK {kakao_key}'}
lat_list, lng_list = [], []
for i in df.index:
    url = f'{base_url}?query={quote(df.addr[i])}'
    result = requests.get(url, headers=header).json()
    lat_list.append(float(result['documents'][0]['y']))
    lng_list.append(float(result['documents'][0]['x']))

# %%
df['위도'] = lat_list
df['경도'] = lng_list
df.head()
# Out:
#       name                     addr         위도          경도
# 0  수원중부경찰서     경기도 수원시 장안구 정자천로 199  37.297932  126.996317
# 1  수원남부경찰서        경기 수원시 영통구 매봉로 52  37.272104  127.054492
# 2  수원서부경찰서      경기 수원시 권선구 서부로 1673  37.258740  126.972264
# 3  안양동안경찰서  경기도 안양시 동안구 동안로159번길 43  37.391209  126.948866
# 4  안양만안경찰서       경기도 안양시 만안구 냉천로 63  37.387334  126.925974

# %% [markdown]
# ##### 지도에 표시하기

# %%
police = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=10)

for i in df.index:
    folium.Marker(
        location=[df.위도[i], df.경도[i]],
        popup=folium.Popup(df.addr[i], max_width=200),
        tooltip=df.name[i]
    ).add_to(police)

title_html = '<h3 align="center" style="font-size:20px">경기남부경찰청 산하 경찰서</h3>'
police.get_root().html.add_child(folium.Element(title_html))
police
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a775fdf03117b05f57e4464c733d6ba7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;경기남부경찰청 산하 경찰서&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a775fdf03117b05f57e4464c733d6ba7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a775fdf03117b05f57e4464c733d6ba7 = L.map(
#                 &quot;map_a775fdf03117b05f57e4464c733d6ba7&quot;,
#                 {
#                     center: [37.33488698359164, 127.05410185290178],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78a40ccf85bcbdc7c28395fb8e74c6a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a775fdf03117b05f57e4464c733d6ba7);
#
#
#             var marker_7704aa8a11b9c1e2f5810a4a88f925f7 = L.marker(
#                 [37.2979319496338, 126.99631718583],
#                 {}
#             ).addTo(map_a775fdf03117b05f57e4464c733d6ba7);
#
#
#         var popup_d35f56b19a15922650207d1c071c9cba = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_4058ec0349ca9638082f342ea5c5a66a = $(`&lt;div id=&quot;html_4058ec0349ca9638082f342ea5c5a66a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 장안구 정자천로 199&lt;/div&gt;`)[0];
#                 popup_d35f56b19a15922650207d1c071c9cba.setContent(html_4058ec0349ca9638082f342ea5c5a66a);
#
#
#
#         marker_7704aa8a11b9c1e2f5810a4a88f925f7.bindPopup(popup_d35f56b19a15922650207d1c071c9cba)
#         ;
#
#
#
#
#             marker_7704aa8a11b9c1e2f5810a4a88f925f7.bindTooltip(
#                 `&lt;div&gt;
#                      수원중부경찰서
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4981e316ce7d4db34f84fae10dd23231 = L.marker(
#                 [37.2721043390665, 127.054492051642],
#                 {}
#             ).addTo(map_a775fdf03117b05f57e4464c733d6ba7);
#
#
#         var popup_d8b0d19aed6c093622dff68a18a2345d = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_c2bb1ab66833f6ab85a101e7b072d04a = $(`&lt;div id=&quot;html_c2bb1ab66833f6ab85a101e7b072d04a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기 수원시 영통구 매봉로 52&lt;/div&gt;`)[0];
#                 popup_d8b0d19aed6c093622dff68a18a2345d.setContent(html_c2bb1ab66833f6ab85a101e7b072d04a);
#
#
#
#         marker_4981e316ce7d4db34f84fae10dd23231.bindPopup(popup_d8b0d19aed6c093622dff68a18a2345d)
#         ;
#
#
#
#
#             marker_4981e316ce7d4db34f84fae10dd23231.bindTooltip(
#                 `&lt;div&gt;
#                      수원남부경찰서
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e934a8fa25199a7fdfbd4176e5462be4 = L.marker(
#                 [37.2587398262097, 126.97226385575],
#                 {}
#             ).addTo(map_a775fdf03117b05f57e4464c733d6ba7);
#
#
#         var popup_62a8c8a9bb8c114e022705b6e67c4355 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_338e72fb096fab1db590ca0d471357a4 = $(`&lt;div id=&quot;html_338e72fb096fab1db590ca0d471357a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기 수원시 권선구 서부로 1673&lt;/div&gt;`)[0];
#                 popup_62a8c8a9bb8c114e022705b6e67c4355.setContent(html_338e72fb096fab1db590ca0d471357a4);
#
#
#
#         marker_e934a8fa25199a7fdfbd4176e5462be4.bindPopup(popup_62a8c8a9bb8c114e022705b6e67c4355)
#         ;
#
#
#
#
#             marker_e934a8fa25199a7fdfbd4176e5462be4.bindTooltip(
#                 `&lt;div&gt;
#                      수원서부경찰서
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1121f1080dab4be4d58dd65fdc34bae0 = L.marker(
#                 [37.3912094396239, 126.948865644818],
#                 {}
#             ).addTo(map_a775fdf03117b05f57e4464c733d6ba7);
#
#
#         var popup_14773bf88a4276fc452bc88ff68e84cf = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_daad09108558f8d5ebbb67eb275d40da = $(`&lt;div id=&quot;html_daad09108558f8d5ebbb67eb275d40da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 안양시 동안구 동안로159번길 43&lt;/div&gt;`)[0];
#                 popup_14773bf88a4276fc452bc88ff68e84cf.setContent(html_daad09108558f8d5ebbb67eb275d40da);
#
#
#
#         marker_1121f1080dab4be4d58dd65fdc34bae0.bindPopup(popup_14773bf88a4276fc452bc88ff68e84cf)
#         ;
#
#
#
#
#             marker_1121f1080dab4be4d58dd65fdc34bae0.bindTooltip(
#                 `&lt;div&g
