# %% [markdown]
# ### 2. 여러가지 플롯

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# ### 1. Bar chart

# %%
y,x=[2,3,1],[0,1,2]
plt.title('Bar Chatr')
plt.bar(x,y)
plt.xticks(x,['가','나','다']),plt.yticks(sorted(y))
plt.xlabel('가나다'),plt.ylabel('빈도수')
plt.show()

# %%
s = pd.Series(np.random.rand(10),index=list('abcdefghij'))
plt.bar(s.index,s.values)
plt.title('Bar chart')
plt.yticks([0,0.2,0.4,0.6,0.8]),plt.xticks([]),plt.grid()
plt.show()

# %%
s.plot(kind='bar')
plt.show()

# %%
df = pd.DataFrame(np.random.rand(20).reshape(10,2),
                  index=list('abcdefghij'),columns=['M',"N"])
plt.bar(df.index,df.M.values)
plt.title('Bar chart')
plt.show()

# %%
import seaborn as sns
titanic =sns.load_dataset('titanic')
titanic['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
# 누운 그래프
s =titanic['class'].value_counts()
plt.figure(figsize=(4,2))
plt.barh(s.index,s.values)
plt.title('타이타닉호의 선실별 승객수')
plt.show()

# %% [markdown]
# ### 2.2 파이 차트(pie chart)

# %%
ratio =[10,15,20,25]     # 합이 100이 아니어도 됩니다.
labels = ['감','귤','배','밤']
plt.pie(ratio, labels=labels,autopct='%.1f%%') #%.1는 소수점 %%는 %단위 쓸려고
plt.title('파이차트')
plt.show()

# %%
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0)  # labels 의 두번째 가 나오게
plt.pie(ratio, labels=labels,autopct='%.1f%%',colors=colors,explode=explode,
        startangle=90,shadow=True)
plt.title('파이차트')
plt.show()

# %% [markdown]
# ##### 3. 히스토그램

# %%
np.random.seed(2023)
x = np.random.randn(1000)   #randn 정규표본
plt.title('히스토 그램')
a, b, _=plt.hist(x,bins=10) # X축이 20개 구간
plt.show()

# %%
#각 구간에 속한 돗수
# array
a
# Out:
# array([  4.,  24.,  57., 135., 194., 210., 193., 116.,  46.,  21.])

# %%
#경계값
#bins
b
# Out:
# array([-3.12153215, -2.54393821, -1.96634427, -1.38875033, -0.81115639,
#        -0.23356245,  0.3440315 ,  0.92162544,  1.49921938,  2.07681332,
#         2.65440726])

# %% [markdown]
# #### 4. 산점도(Scatter plot)

# %%
np.random.seed(2023)
X,Y = np.random.normal(2,2,100),np.random.randn(100)
plt.figure(figsize=(5,3))
plt.scatter(X,Y)
plt.title('산점도')
plt.show()

# %%
colors = np.random.rand(100)
plt.figure(figsize=(5,3))
plt.scatter(X,Y,c=colors,alpha=0.5)  #투명도 alpha
plt.title('색상을 준 산점도')
plt.show()

# %%
s = 500 * np.random.rand(100)    #차트 안에 크기
plt.figure(figsize=(5,3))
plt.scatter(X,Y,s=s,c=colors,alpha=0.5)  #s=size
plt.title('색상을 준 산점도')
plt.show()

# %% [markdown]
# #### 5. 이미지 보기

# %%
from PIL import Image
img =Image.open('C:/Users/YONSAI/Pictures/고양이.jpg')
plt.figure(figsize=(5,3))
plt.imshow(img);

# %%
# x,y 축 제거 하고 이미지만 보이기
plt.imshow(img);plt.axis('off');

# %% [markdown]
# #### 6.Boxpolt

# %%
iris = sns.load_dataset('iris')
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
ssl = iris[iris.species == 'setosa'].sepal_length
ssw = iris[iris.species == 'setosa'].sepal_width
plt.boxplot((ssl,ssw), labels=['sepal_length', 'sepal_width'])
plt.title('Setosa 품종의 꽃받침 길이/너비')
plt.show()
